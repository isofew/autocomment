# %%
# !conda install -y GitPython
# Out:
# Fetching package metadata .........
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /Users/user/anaconda3:
# #
# gitpython                 2.1.3                    py36_0

# %%
from git import Repo
import pandas as pd
import re

# %%
repo = Repo('~/youtube-dl')

# %%
data = {
    'author_email': [],
    'authored_date': [],
    'summary': [],
    'diffs': [], # to avoid the confliction with pd.DataFrame.diff
    'num_add': [],
    'num_del': []
}

this = repo.commit('master')
cnt = 0

while True:
    try:
        parent = this.parents[0]
    except:
        break

    record = {
        'author_email': this.author.email,
        'authored_date': this.authored_date,
        'summary': this.summary,
        'diffs': '\r\n\r\n'.join(list(map(str, this.diff(parent, create_patch=True)))),
        'num_add': this.stats.total['insertions'],
        'num_del': this.stats.total['deletions']
    }
    
    for k in record:
        data[k].append(record[k])
    
    this = parent
    
    cnt += 1
    if cnt % 1000 == 0:
        print('%d commits loaded' % cnt)
# Out:
# 1000 commits loaded
# 2000 commits loaded
# 3000 commits loaded
# 4000 commits loaded
# 5000 commits loaded
# 6000 commits loaded
# 7000 commits loaded
# 8000 commits loaded
# 9000 commits loaded
# 10000 commits loaded
# 11000 commits loaded
# 12000 commits loaded

# %%
data = pd.DataFrame(data)

# format, clean up, and new feature
data.authored_date = pd.to_datetime(data.authored_date, unit='s')
data.diffs = data.diffs.map(lambda d: re.sub(r'\n[lr]hs: \d+ \| [0-9a-f]+', '', d))
data['words'] = data.diffs.map(lambda d: re.findall(r'[A-Za-z][A-Za-z0-9]+', d))

data.sample(5)
# Out:
#                               author_email       authored_date  \
# 8439                      phihag@phihag.de 2014-07-11 13:38:18
# 11467                     phihag@phihag.de 2012-11-27 23:13:40
# 4541             marco.ferragina@gmail.com 2015-10-14 09:11:52
# 11145  jaime.marquinez.ferrandiz@gmail.com 2013-04-20 10:50:14
# 819                   remitamine@gmail.com 2017-02-21 13:38:00
#
#                                                    diffs  num_add  num_del  \
# 8439   youtube_dl/extractor/common.py\n==============...       60       13
# 11467  youtube_dl/InfoExtractors.py\n================...        2        2
# 4541   docs/supportedsites.md\n======================...       84        0
# 11145  youtube_dl/FileDownloader.py\n================...       21       12
# 819    youtube_dl/extractor/ninecninemedia.py\n======...        1        0
#
#                                                  summary  \
# 8439   [screencast] Add suppot for more video types (...
# 11467                                One more except..as
# 4541                               [vidto] Add extractor
# 11145  Allows to specify which IE should be used for ...
# 819            [ninecninemedia] use geo bypass mechanism
#
#                                                    words
# 8439   [youtube, dl, extractor, common, py, class, In...
# 11467  [youtube, dl, InfoExtractors, py, class, Sound...
# 4541   [docs, supportedsites, md, VideoTt, video, tt,...
# 11145  [youtube, dl, FileDownloader, py, if, os, name...
# 819    [youtube, dl, extractor, ninecninemedia, py, c...

# %%
train = data[data.authored_date < '2017-01-01']
train.sample(5)
# Out:
#            author_email       authored_date  \
# 4285   dstftw@gmail.com 2015-12-11 15:11:45
# 3718   dstftw@gmail.com 2016-02-11 16:02:37
# 8274   phihag@phihag.de 2014-08-21 23:52:56
# 10511  phihag@phihag.de 2013-08-28 10:47:38
# 4884   dstftw@gmail.com 2015-09-26 19:10:39
#
#                                                    diffs  num_add  num_del  \
# 4285   youtube_dl/extractor/funimation.py\n==========...        2        1
# 3718   youtube_dl/extractor/pbs.py\n=================...        8        4
# 8274   youtube_dl/extractor/__init__.py\n============...      148        0
# 10511  youtube_dl/extractor/addanime.py\n============...        0        6
# 4884   youtube_dl/extractor/eagleplatform.py\n=======...        3        1
#
#                                                  summary  \
# 4285                                  [funimation] PEP 8
# 3718              [pbs] Fix multi part videos extraction
# 8274   Merge remote-tracking branch 'terminalmage/add...
# 10511                              Remove unused imports
# 4884   [eagleplatform] Simplify secure mp4 constructi...
#
#                                                    words
# 4285   [youtube, dl, extractor, funimation, py, from,...
# 3718   [youtube, dl, extractor, pbs, py, class, PBSIE...
# 8274   [youtube, dl, extractor, init, py, from, orf, ...
# 10511  [youtube, dl, extractor, addanime, py, import,...
# 4884   [youtube, dl, extractor, eagleplatform, py, cl...

# %%
test = data[data.authored_date >= '2017-01-01']
test_ans = test.summary

test = test.drop('summary', axis=1)
test.sample(5)
# Out:
#               author_email       authored_date  \
# 485       dstftw@gmail.com 2017-04-15 13:30:51
# 1093      dstftw@gmail.com 2017-01-18 16:10:00
# 331   remitamine@gmail.com 2017-05-07 07:58:34
# 221       dstftw@gmail.com 2017-05-28 17:33:24
# 495       dstftw@gmail.com 2017-04-13 17:29:36
#
#                                                   diffs  num_add  num_del  \
# 485   youtube_dl/extractor/brightcove.py\n==========...       34       25
# 1093  .github/ISSUE_TEMPLATE.md\n===================...        5        5
# 331   youtube_dl/extractor/nbc.py\n=================...       29       65
# 221   ChangeLog\n===================================...       11        0
# 495   ChangeLog\n===================================...       20        0
#
#                                                   words
# 485   [youtube, dl, extractor, brightcove, py, class...
# 1093  [github, ISSUE, TEMPLATE, md, Make, sure, you,...
# 331   [youtube, dl, extractor, nbc, py, from, utils,...
# 221   [ChangeLog, version, unreleased, Extractors, y...
# 495   [ChangeLog, version, unreleased, Core, downloa...

# %%
train.to_csv('train.csv')
test.to_csv('test.csv')
test_ans.to_csv('test_ans.csv')
